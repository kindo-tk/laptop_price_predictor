# %% [markdown]
# # Laptop Price Predictor

# %% [markdown]
# ### Importing the necessary libraries

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.ensemble import StackingRegressor

import warnings
warnings.filterwarnings('ignore')

import joblib

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv("../datasets/laptop_data.csv")

df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# ### Dropping the unnecessary first column

# %%
df.drop(columns = 'Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %% [markdown]
# ### Checking for the missing values

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ### Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# np.int64(29)

# %% [markdown]
# ### Dropping the duplicate values

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ### Filtering the RAM, weight columns by removing the word GB, Kg and converting to numerical type

# %%
df['Ram'] = df['Ram'].str.replace('GB','')

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Weight']
# Out:
# 0       1.37
# 1       1.34
# 2       1.86
# 3       1.83
# 4       1.37
#         ...
# 1269     2.2
# 1270     1.8
# 1271     1.3
# 1272     1.5
# 1273    2.19
# Name: Weight, Length: 1274, dtype: object

# %%
df['Ram'] = df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 109.5+ KB

# %%
sns.displot(df['Price'])
plt.show()

# %% [markdown]
# - the data is left skewed, maximum laptops have price in lower range

# %%
df['Company'].value_counts().plot(kind = 'bar')
plt.show()

# %%
sns.barplot(x = df['Company'], y = df['Price'], palette='viridis')
plt.xticks(rotation = 45)
plt.show()

# %%
df['TypeName'].value_counts().plot(kind = 'pie')
plt.show()

# %%
sns.barplot(x = df['TypeName'], y = df['Price'])
plt.xticks(rotation = 45)
plt.show()

# %%
sns.displot(df['Inches'])
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                505
# 1366x768                                         262
# IPS Panel Full HD 1920x1080                      226
# IPS Panel Full HD / Touchscreen 1920x1080         51
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['TouchScreen'] = df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df['TouchScreen'].value_counts().plot(kind = 'bar')
plt.show()

# %%
sns.barplot(x = df['TouchScreen'], y = df['Price'])
plt.show()

# %% [markdown]
# - Laptop being touch screen affects the pricing

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df['Ips'].value_counts().plot(kind = 'bar')
plt.show()

# %%
sns.barplot(x = df['Ips'], y = df['Price'])
plt.show()

# %%
temp = df['ScreenResolution'].str.split('x',n = 1 , expand=True)

# %%
df['X_Res'] = temp[0]
df['Y_Res'] = temp[1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df['X_Res'] = df['X_Res'].str.split()

# %%
df['X_Res'] = df['X_Res'].apply(lambda x: int(x[-1]))

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df['Y_Res'] = df['Y_Res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int32
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float32
#  10  Price             1274 non-null   float64
#  11  TouchScreen       1274 non-null   int64
#  12  Ips               1274 non-null   int64
#  13  X_Res             1274 non-null   int64
#  14  Y_Res             1274 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
df['ppi'] = (((df['X_Res']**2) + (df['Y_Res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.066990
# Ram            0.740106
# Weight         0.212192
# Price          1.000000
# TouchScreen    0.188631
# Ips            0.250358
# X_Res          0.552074
# Y_Res          0.548111
# ppi            0.469539
# Name: Price, dtype: float64

# %%
df.drop('ScreenResolution', axis = 1, inplace = True)

# %%
df.drop(columns = ['Inches','X_Res','Y_Res'], axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1271  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1272  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1273      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       132
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M 6Y54 1.1GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# AMD E-Series 9000 2.2GHz           1
# Intel Core M 6Y30 0.9GHz           1
# AMD A9-Series 9410 2.9GHz          1
# Name: count, Length: 118, dtype: int64

# %%
df['CPU_Name'] = df['Cpu'].apply(lambda x: ' '.join(x.split()[0:3]))

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1271  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1272  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1273      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['CPU_Brand'] = df['CPU_Name'].apply(fetch_processor)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1269    Asus            Notebook            Intel Core i7 6500U 2.5GHz    4
# 1270  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1271  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1272  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1273      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
#
# ...

# %%
df['CPU_Brand'].value_counts().plot(kind='bar')
plt.show()

# %%
sns.barplot(x = df['CPU_Brand'], y = df['Price'])
plt.xticks(rotation = 45)
plt.show()

# %%
df.drop(columns = ['Cpu','CPU_Name'], axis = 1 , inplace = True)

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1269    Asus            Notebook    4            500GB HDD
# 1270  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1271  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1272  Lenovo            Notebook    2   64GB Flash Storage
# 1273      HP            Notebook    6              1TB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df['Ram'].value_counts().plot(kind = 'bar')
plt.show()

# %%
sns.barplot(x = df['Ram'], y = df['Price'])
plt.xticks(rotation = 45)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          215
# 500GB HDD                        123
# 512GB SSD                        114
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         74
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                36
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 64GB Flash Storage                13
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
storage_types = ["HDD", "SSD", "Hybrid", "Flash Storage"]

def parse_memory(mem):
    result = {t: 0 for t in storage_types}
    if not isinstance(mem, str):
        return result

    parts = mem.split("+")

    for part in parts:
        part = part.strip()

        size_match = re.search(r'(\d+\.?\d*)', part)
        if not size_match:
            continue

        size = float(size_match.group(1))

        if "TB" in part:
            size *= 1000

        for stype in storage_types:
            if stype in part:
                result[stype] += int(size)

    return result

# %%
memory_features = df["Memory"].apply(parse_memory).apply(pd.Series)
df = pd.concat([df, memory_features], axis=1)
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1269    Asus            Notebook    4            500GB HDD
# 1270  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1271  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1272  Lenovo            Notebook    2   64GB Flash Storage
# 1273      HP            Notebook    6              1TB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df[["HDD", "SSD", "Hybrid", "Flash Storage"]].head()
# Out:
#    HDD  SSD  Hybrid  Flash Storage
# 0    0  128       0              0
# 1    0    0       0            128
# 2    0  256       0              0
# 3    0  512       0              0
# 4    0  256       0              0

# %%
df.drop('Memory', axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1269    Asus            Notebook    4           Nvidia GeForce 920M
# 1270  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1271  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1272  Lenovo            Notebook    2             Intel HD Graphics
# 1273      HP            Notebook    6            AMD Radeon R5 M330
#
#            OpSys  Weight        Price  TouchScreen  Ips         ppi  \
# 0          macOS    1.37   71378.6832            0    1  226.983005
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Ram              0.740106
# Weight           0.212192
# Price            1.000000
# TouchScreen      0.188631
# Ips              0.250358
# ppi              0.469539
# HDD             -0.098011
# SSD              0.669957
# Hybrid           0.022533
# Flash Storage   -0.037176
# Name: Price, dtype: float64

# %%
df.drop(columns = ['Hybrid','Flash Storage'], inplace = True)

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      279
# Intel HD Graphics 520      181
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['GPU_brand'] = df['Gpu'].apply(lambda x: x.split()[0])

# %%
df['GPU_brand'].value_counts()
# Out:
# GPU_brand
# Intel     703
# Nvidia    396
# AMD       174
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['GPU_brand']!='ARM']
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1269    Asus            Notebook    4           Nvidia GeForce 920M
# 1270  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1271  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1272  Lenovo            Notebook    2             Intel HD Graphics
# 1273      HP            Notebook    6            AMD Radeon R5 M330
#
#            OpSys  Weight        Price  TouchScreen  Ips         ppi  \
# 0          macOS    1.37   71378.6832            0    1  226.983005
# ...

# %%
df['GPU_brand'].value_counts()
# Out:
# GPU_brand
# Intel     703
# Nvidia    396
# AMD       174
# Name: count, dtype: int64

# %%
sns.barplot(x = df['GPU_brand'], y = df['Price'])
plt.xticks(rotation = 45)
plt.show()

# %%
df.drop('Gpu', axis = 1, inplace = True)

# %%
df
# Out:
#      Company            TypeName  Ram       OpSys  Weight        Price  \
# 0      Apple           Ultrabook    8       macOS    1.37   71378.6832
# 1      Apple           Ultrabook    8       macOS    1.34   47895.5232
# 2         HP            Notebook    8       No OS    1.86   30636.0000
# 3      Apple           Ultrabook   16       macOS    1.83  135195.3360
# 4      Apple           Ultrabook    8       macOS    1.37   96095.8080
# ...      ...                 ...  ...         ...     ...          ...
# 1269    Asus            Notebook    4  Windows 10    2.20   38378.6496
# 1270  Lenovo  2 in 1 Convertible    4  Windows 10    1.80   33992.6400
# 1271  Lenovo  2 in 1 Convertible   16  Windows 10    1.30   79866.7200
# 1272  Lenovo            Notebook    2  Windows 10    1.50   12201.1200
# 1273      HP            Notebook    6  Windows 10    2.19   40705.9200
#
#       TouchScreen  Ips         ppi              CPU_Brand   HDD  SSD GPU_brand
# ...

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1047
# No OS             66
# Linux             58
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.displot(df['Weight'])
plt.show()

# %%
df.drop(columns = ['OpSys'], inplace = True)

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(10, 6))
sns.heatmap(
    corr,
    annot=True,
    cmap="viridis",
    fmt=".2f",
    linewidths=0.5
)
plt.title("Correlation Matrix")
plt.show()

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1269    Asus            Notebook    4    2.20   38378.6496            0    0
# 1270  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1271  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1272  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1273      HP            Notebook    6    2.19   40705.9200            0    0
#
# ...

# %% [markdown]
# - Price column is skewed so we apply log transformation

# %%
sns.displot(df['Price'])
plt.show()

# %%
sns.displot(np.log(df['Price']))
plt.show()

# %% [markdown]
# ### Saving the filtered data

# %%
df.to_csv("../datasets/cleaned_data.csv", index=False)

# %% [markdown]
# ### Splitting the features and target

# %%
x = df.drop(columns = ['Price'])
y = np.log1p(df['Price'])

# %% [markdown]
# ### Train test split of the data

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.15, random_state=42)

# %% [markdown]
# ### Fitting models

# %%
categorical_cols = ['Company', 'TypeName', 'CPU_Brand', 'GPU_brand', 'os']
numerical_cols = [col for col in x_train.columns if col not in categorical_cols]

# %%
preprocessor_scaled = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
        ('num', StandardScaler(), numerical_cols)
    ],
    remainder='drop'
)


preprocessor_tree = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols)
    ],
    remainder='passthrough'
)

# %% [markdown]
# ### Fitting Linear, Ridge, Lasso

# %%
linear_models = {
    "LinearRegression": LinearRegression(),
    "Ridge": Ridge(alpha=1.0),
    "Lasso": Lasso(alpha=0.001)
}

linear_pipelines = {
    name: Pipeline([
        ('preprocess', preprocessor_scaled),
        ('model', model)
    ])
    for name, model in linear_models.items()
}

for model in linear_pipelines.values():
    model.fit(x_train, y_train)

# %% [markdown]
# ### KNN and SVR

# %%
knn_pipe = Pipeline([
    ('preprocess', preprocessor_scaled),
    ('model', KNeighborsRegressor(n_neighbors=5))
])

svr_pipe = Pipeline([
    ('preprocess', preprocessor_scaled),
    ('model', SVR(kernel='rbf', C=100, epsilon=0.1))
])

knn_pipe.fit(x_train, y_train)
svr_pipe.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['Company', 'TypeName',
#                                                    'CPU_Brand', 'GPU_brand',
#                                                    'os']),
#                                                  ('num', StandardScaler(),
#                                                   ['Ram', 'Weight',
#                                                    'TouchScreen', 'Ips', 'ppi',
#                                                    'HDD', 'SSD'])])),
#                 ('model', SVR(C=100))])

# %% [markdown]
# ### Decision Tree with hyper parameter tuning

# %%
dt_pipe = Pipeline([
    ('preprocess', preprocessor_tree),
    ('model', DecisionTreeRegressor(random_state=42))
])

dt_params = {
    'model__max_depth': [None, 5, 8, 10, 20],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 5]
}

dt_search = GridSearchCV(
    dt_pipe,
    dt_params,
    cv=5,
    scoring='r2',
    n_jobs=-1,
)

dt_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'CPU_Brand',
#                                                                           'GPU_brand',
#                                                                           'os'])])),
#                                        ('model',
# ...

# %% [markdown]
# ### Random Forest with tuning

# %%
rf_pipe = Pipeline([
    ('preprocess', preprocessor_tree),
    ('model', RandomForestRegressor(random_state=42, n_jobs=-1))
])

rf_params = {
    'model__n_estimators': [200, 400, 600],
    'model__max_depth': [None, 10, 20, 30],
    'model__min_samples_split': [2, 5, 10],
    'model__min_samples_leaf': [1, 2, 4]
}

rf_search = GridSearchCV(
    rf_pipe,
    rf_params,
    cv=5,
    scoring='r2',
    n_jobs=-1,
)

rf_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'CPU_Brand',
#                                                                           'GPU_brand',
#                                                                           'os'])])),
#                                        ('model',
# ...

# %% [markdown]
# ### Gradient Boosting with tuning

# %%
gbr_pipe = Pipeline([
    ('preprocess', preprocessor_tree),
    ('model', GradientBoostingRegressor(random_state=42))
])

gbr_params = {
    'model__n_estimators': [100, 200, 300],
    'model__learning_rate': [0.03, 0.05, 0.1],
    'model__max_depth': [3, 4, 5]
}

gbr_search = GridSearchCV(
    gbr_pipe,
    gbr_params,
    cv=5,
    scoring='r2',
    n_jobs=-1,
)

gbr_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'CPU_Brand',
#                                                                           'GPU_brand',
#                                                                           'os'])])),
#                                        ('model',
# ...

# %% [markdown]
# ### AdaBoost with tuning

# %%
ada_pipe = Pipeline([
    ('preprocess', preprocessor_tree),
    ('model', AdaBoostRegressor(random_state=42))
])

ada_params = {
    'model__n_estimators': [100, 200, 300],
    'model__learning_rate': [0.03, 0.05, 0.1]
}

ada_search = GridSearchCV(
    ada_pipe,
    ada_params,
    cv=5,
    scoring='r2',
    n_jobs=-1,
)

ada_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'CPU_Brand',
#                                                                           'GPU_brand',
#                                                                           'os'])])),
#                                        ('model',
# ...

# %% [markdown]
# ### XGBoost with tuning

# %%
xgb_pipe = Pipeline([
    ('preprocess', preprocessor_tree),
    ('model', XGBRegressor(
        objective='reg:squarederror',
        random_state=42,
        n_jobs=-1
    ))
])

xgb_params = {
    'model__n_estimators': [300, 500],
    'model__max_depth': [4, 6, 8],
    'model__learning_rate': [0.03, 0.05, 0.1],
    'model__subsample': [0.8, 1.0],
    'model__colsample_bytree': [0.8, 1.0]
}

xgb_search = GridSearchCV(
    xgb_pipe,
    xgb_params,
    cv=5,
    scoring='r2',
    n_jobs=-1,
)

xgb_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('cat',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['Company',
#                                                                           'TypeName',
#                                                                           'CPU_Brand',
#                                                                           'GPU_brand',
#                                                                           'os'])])),
#                                        ('model',
# ...

# %% [markdown]
# ### Voting Regressor

# %%
rf_best = rf_search.best_estimator_
xgb_best = xgb_search.best_estimator_
gbr_best = gbr_search.best_estimator_ 

voting = VotingRegressor(estimators=[
    ('rf', rf_best), 
    ('xgb', xgb_best), 
    ('gb', gbr_best)
])

voting.fit(x_train, y_train)
# Out:
# VotingRegressor(estimators=[('rf',
#                              Pipeline(steps=[('preprocess',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('cat',
#                                                                                OneHotEncoder(drop='first',
#                                                                                              sparse_output=False),
#                                                                                ['Company',
#                                                                                 'TypeName',
#                                                                                 'CPU_Brand',
#                                                                                 'GPU_brand',
#                                                                                 'os'])])),
# ...

# %% [markdown]
# ### Comparison of all the models

# %%
models = {
    "LinearRegression": linear_pipelines["LinearRegression"],
    "Ridge": linear_pipelines["Ridge"],
    "Lasso": linear_pipelines["Lasso"],
    "KNN": knn_pipe,
    "SVR": svr_pipe,
    "DecisionTree": dt_search.best_estimator_,
    "RandomForest": rf_search.best_estimator_,
    "GradientBoosting": gbr_search.best_estimator_,
    "AdaBoost": ada_search.best_estimator_,
    "XGBoost": xgb_search.best_estimator_,
    "Voting Regressor": voting
}

for name, model in models.items():
    y_pred = np.expm1(model.predict(x_test))
    y_true = np.expm1(y_test)
    print(name, "R2:", r2_score(y_true, y_pred))
# Out:
# LinearRegression R2: 0.7593218374189028
# Ridge R2: 0.7587725342722675
# Lasso R2: 0.7487902672645965
# KNN R2: 0.7121150699998884
# SVR R2: 0.737686522498886
# DecisionTree R2: 0.7475618731687539
# RandomForest R2: 0.8196750352120744
# GradientBoosting R2: 0.7041075611918769
# AdaBoost R2: 0.5967510547110151
# XGBoost R2: 0.8394591556363765
# Voting Regressor R2: 0.803241352941631

# %% [markdown]
# ### Saving the best model

# %%
best_model_name = max(
    models,
    key=lambda m: r2_score(
        np.expm1(y_test),
        np.expm1(models[m].predict(x_test))
    )
)

print(f"Best Model Found: {best_model_name}")

best_model = models[best_model_name]
print(f"Type of best_model: {type(best_model)}")

if hasattr(best_model, 'predict'):
    joblib.dump(best_model, "../models/best_laptop_price_model.pkl")
    print("Model saved successfully as 'best_laptop_price_model.pkl'")
else:
    print("ERROR: 'best_model' is NOT a model. It is:", type(best_model))
    print("Please check your 'models' dictionary definition.")
# Out:
# Best Model Found: XGBoost
# Type of best_model: <class 'sklearn.pipeline.Pipeline'>
# Model saved successfully as 'best_laptop_price_model.pkl'
